# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mikoajfish99/marine-animal-images")

print("Path to dataset files:", 'images/')
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 227M/227M [02:10<00:00, 1.83MB/s]
# Extracting files...
# Path to dataset files: images/

# %%
print(path)
# Out:
# C:\Users\Elabor Emmanuel\.cache\kagglehub\datasets\mikoajfish99\marine-animal-images\versions\1
